# %% [markdown]
# UD02 USAR EL PERCEPTRÓN

# %% [markdown]
#     PREGUNTA 1: ¿Porqué no inicializar los pesos de la neurona directamente todos a 0?
#     O Porque el learning rate también se queda a 0.
#     O Porque el vector de pesos w representa una línea recta y si inicialmente es 0, cuando falla al
#     predecir y actualiza, al multiplicarlo, cambia su tamaño pero nunca su dirección.

# %% [markdown]
# Porque el vector de pesos w representa una línea recta y si inicialmente es 0, cuando falla al
# predecir y actualiza, al multiplicarlo, cambia su tamaño pero nunca su dirección

# %% [markdown]
#     PREGUNTA 2: ¿Para qué sirve el parámetro header del método read_csv()?

# %% [markdown]
# El parámetro header en el método read_csv vale para decirle donde está el encabezado de las columnas. En este caso le hemos dicho que no hay encabezado y los nombres de las columnas serán asignados por pandas como números enteros 0, 1, 2..

# %% [markdown]
#     PREGUNTA 3: Pon tu nombre y primer apellido al título del gráfico tal y como te propone el código y
#     entrega una captura del gráfico con el nombre u02_p01_03.png

# %%
from IPython.display import Image

#Imagen adjunta en la carpeta
Image("UD02_P01_03.png")

# %% [markdown]
#     PREGUNTA 4: Viendo como están distribuidas las flores del dataset y teniendo en cuenta que el
#     perceptrón es un clasificador lineal, ¿debería ser capaz de encontrar una línea que separe
#     U02 ACTIVIDAD 1 página 5 / 6
#     perfectamente los dos tipos o clases de flores? Traza una línea que separe ambas clases usando un
#     programa de edición de imágenes y la entregas como u02_p01_04.png.
#     ¿Puedes decirme qué linea es? Darme aproximadamente su ecuación

# %% [markdown]
# Si los datos son linealmente separables el perceptrón sí podrá encontrar una línea que los separe

# %% [markdown]
# La línea aproximada podría ser algo así
#
# $$
# x_2 = 0.5 \cdot x_1 - 1.5
# $$

# %%
from IPython.display import Image

#Entiendo que como pides hacerlo con un programa de edición de imágenes
#hay que hacerlo así aproximado
#Imagen adjunta en la carpeta
Image("UD02_P01_04.png")

# %% [markdown]
#     PREGUNTA 5: Pon tu nombre y primer apellido al título del gráfico tal y como te propone el código y
#     entrega una captura del gráfico con el nombre U02_P01_05.png

# %%
from IPython.display import Image

#Imagen adjunta en la carpeta
Image("UD02_P01_05.png")

# %% [markdown]
#     PREGUNTA 6: ¿Sería cierto decir que durante el entrenamiento en la época 2 y 3 es cuando comete más errores el modelo?

# %% [markdown]
# Sí

# %% [markdown]
#     Marca la época en que comienza a converger el modelo?

# %% [markdown]
# 6

# %% [markdown]
#     Si bajas el learning rate a 0.01 (el parámetro eta) ¿El modelo converge?

# %% [markdown]
# Más lentamente

# %% [markdown]
#     Marca la afirmación correcta sobre este gráfico que acabamos de generar:

# %% [markdown]
# Sirve para vigilar durante el entrenamiento, la cantidad de errores que va cometiendo

# %% [markdown]
#     Al acabar de entrenar la cantidad de errores que comete es 0. ¿Significa que tenemos un modelo
#     perfecto?

# %% [markdown]
#  No. Necesitamos saber como se comporta con datos que no ha usado para entrenar

# %% [markdown]
#     PREGUNTA 7: Pon tu nombre y primer apellido al título del gráfico y entrega una captura del gráfico
#     con el nombre u02_p01_07.png

# %%
from IPython.display import Image

#Imagen adjunta en la carpeta
Image("UD02_P01_07.png")
